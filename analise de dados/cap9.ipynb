# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Capítulo 9 - Plotagem e visualização

# %%
data = np.arange(10)

# %%
plt.plot(data)

# %% [markdown]
# ### Figuras e subplotagens

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(2, 2, 1)

# %%
ax2 = fig.add_subplot(2, 2, 2)

# %%
ax3 = fig.add_subplot(2, 2, 3)

# %%
fig = plt.figure(figsize=((10, 10)))
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
_ = ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))
plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
fig, axes = plt.subplots(2, 3)

# %%
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# 🗒️ Opções de pyplot.subplots - pág 469

# %% [markdown]
# ### Ajustando o espaçamento em torno das subplotagens

# %%
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=None)

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0)

# %% [markdown]
# ### Cores, marcadores e estilos de linha

# %% [markdown]
# ```ax.plot(x, y, 'g--')```

# %% [markdown]
# ```ax.plot(x, y, linestyle='--', color='g')```

# %%
plt.plot(np.random.randn(30).cumsum(), 'ko--')

# %%
plt.plot(np.random.randn(30).cumsum(), color='k', linestyle='dashed', marker='o')

# %%
data = np.random.randn(30).cumsum()

# %%
plt.plot(data, 'k--', label='Default')

plt.plot(data, 'k-', drawstyle='steps-post', label='steps-post')

plt.legend(loc='best')

# %% [markdown]
# ### Tiques, rótulos e legendas

# %% [markdown]
# ### Definindo o título, os rótulos dos eixos, os tiques e os rótulos dos tiques

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ticks = ax.set_xticks([0, 250, 500, 750, 1000])

labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='small')

ax.set_title('My first matplotlib plot')

ax.set_xlabel('Stages')

ax.plot(np.random.randn(1000).cumsum())

# %% [markdown]
# ### Acrescentando legendas

# %%
from numpy.random import randn

# %%
fig = plt.figure(figsize=((10, 10)));
ax = fig.add_subplot(1, 1, 1)

ax.plot(randn(1000).cumsum(), 'k', label='one')

ax.plot(randn(1000).cumsum(), 'k--', label='two')

ax.plot(randn(1000).cumsum(), 'k.', label='three')

ax.legend(loc='best')

# %% [markdown]
# ### Anotações e desenhos em uma subplotagem

# %%
from datetime import datetime

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
data = pd.read_csv('examples/spx.csv', index_col=0,
                   parse_dates=True)
spx = data['SPX']

spx.plot(ax=ax, style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, 
                xy=(date, spx.asof(date) + 75),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor='black', 
                                headwidth=4,
                                width=2,
                                headlength=4),
                horizontalalignment='left', 
                verticalalignment='top')

# Faz um zoom no período de 2007 a 2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])

ax.set_title('Important dates in the 2008-2008 financial crisis')
# Out:
# Text(0.5, 1.0, 'Important dates in the 2008-2008 financial crisis')

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
                   color='g', alpha=0.5)

ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %% [markdown]
# ### Salvando plotagens em arquivos

# %% [markdown]
# ```plt.savefig('figpath.png', dpi=400, bbox_inches='tight')```

# %% [markdown]
# 🗒️ Opções de figure.savefig - pág 484

# %% [markdown]
# ### Configuração da matplotlib

# %%
plt.rc('figure', figsize=(10,10))

# %%
font_options = {'family': 'monospace', 
                'weight': 'bold', 
                'size': 'small'}
plt.rc('font', **font_options)

# %% [markdown]
# ## 9.2 - Plottagem com o pandas e o seaborn

# %% [markdown]
# ### Plotagens de linha

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))

# %%
s.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
                  columns=['A', 'B', 'C', 'D'],
                  index=np.arange(0, 100, 10))

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 🗒️ Argumentos do método Series.plot - pág 489

# %% [markdown]
# 🗒️ Argumentos de plotagem específicos para DataFrame - pág 490

# %% [markdown]
# ### Plotagem de barras

# %%
fig, axes = plt.subplots(2, 1)

data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))

data.plot.bar(ax=axes[0], color='k', alpha=0.7)

data.plot.barh(ax=axes[1], color='k', alpha=0.7)
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(6, 4),
                  index=['one', 'two', 'three', 'four', 'five', 'six'],
                  columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))

# %%
df
# Out:
# Genus         A         B         C         D
# one    0.955455  0.200980  0.374883  0.867894
# two    0.717442  0.205850  0.218508  0.315012
# three  0.168243  0.510277  0.782273  0.238525
# four   0.254140  0.581355  0.833032  0.166905
# five   0.926894  0.892528  0.023066  0.164273
# six    0.885323  0.448307  0.398142  0.436360

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh(stacked=True, alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
tips = pd.read_csv('examples/tips.csv')

# %%
party_counts = pd.crosstab(tips['day'], tips['size'])

# %%
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
party_counts = party_counts.loc[:, 2:5]

# %%
party_counts
# Out:
# size   2   3   4  5
# day
# Fri   16   1   1  0
# Sat   53  18  13  1
# Sun   39  15  18  3
# Thur  48   4   5  1

# %%
party_pcts = party_counts.div(party_counts.sum(1), axis=0)

# %%
party_pcts
# Out:
# size         2         3         4         5
# day
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# Thur  0.827586  0.068966  0.086207  0.017241

# %%
party_pcts.plot.bar()
# Out:
# <AxesSubplot:xlabel='day'>

# %%
import seaborn as sns

# %%
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])

# %%
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size   tip_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.063204
# 1       10.34  1.66     No  Sun  Dinner     3  0.191244
# 2       21.01  3.50     No  Sun  Dinner     3  0.199886
# 3       23.68  3.31     No  Sun  Dinner     2  0.162494
# 4       24.59  3.61     No  Sun  Dinner     4  0.172069

# %%
sns.barplot(x='tip_pct', y='day', data=tips, orient='h')
# Out:
# <AxesSubplot:xlabel='tip_pct', ylabel='day'>

# %%
sns.barplot(x='tip_pct', y='day', hue='time', data=tips, orient='h')
# Out:
# <AxesSubplot:xlabel='tip_pct', ylabel='day'>

# %% [markdown]
# ### Histogramas e plotagens de densidade

# %%
tips['tip_pct'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
tips['tip_pct'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
comp1 = np.random.normal(0, 1, size=200)

comp2 = np.random.normal(10, 2, size=200)

values = pd.Series(np.concatenate([comp1, comp2]))

sns.distplot(values, bins=100, color='k')
# Out:
# /tmp/ipykernel_5596/2983502612.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(values, bins=100, color='k')
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### Plotagens de dispersão ou de pontos

# %%
macro = pd.read_csv('examples/macrodata.csv')

data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]

trans_data = np.log(data).diff().dropna()

trans_data[-5:]
# Out:
#           cpi        m1  tbilrate     unemp
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560

# %%
trans_data[['m1', 'unemp']]
# Out:
#            m1     unemp
# 1    0.014215 -0.128617
# 2   -0.008505  0.038466
# 3   -0.003565  0.055060
# 4   -0.002861 -0.074108
# 5    0.004289  0.000000
# ..        ...       ...
# 198  0.045361  0.105361
# 199  0.066753  0.139762
# 200  0.010286  0.160343
# 201  0.037461  0.127339
# 202  0.012202  0.042560
#
# [202 rows x 2 columns]

# %%
sns.regplot(x='m1', y='unemp', data=trans_data)
# Out:
# <AxesSubplot:xlabel='m1', ylabel='unemp'>

# %%
sns.pairplot(trans_data, diag_kind='kde', plot_kws={'alpha': 0.2})

# %% [markdown]
# ### Grades de faceta e dados de categoria

# %%
# sns.factorplot(x='day', y='tip_pct', hue='time', 
#                col='smoker', kind='bar', 
#                data=tips[tips.tip_pct < 1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/saulo/Arquivos/anotacoes/analise de dados/cap9.ipynb Cell 78 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/saulo/Arquivos/anotacoes/analise%20de%20dados/cap9.ipynb#Y163sZmlsZQ%3D%3D?line=0'>1</a> sns.factorplot(x='day', y='tip_pct', hue='time',
#       <a href='vscode-notebook-cell:/home/saulo/Arquivos/anotacoes/analise%20de%20dados/cap9.ipynb#Y163sZmlsZQ%3D%3D?line=1'>2</a>                col='smoker', kind='bar',
#       <a href='vscode-notebook-cell:/home/saulo/Arquivos/anotacoes/analise%20de%20dados/cap9.ipynb#Y163sZmlsZQ%3D%3D?line=2'>3</a>                data=tips[tips.tip_pct < 1])
#
# AttributeError: module 'seaborn' has no attribute 'factorplot'

# %%
# sns.factorplot(x='day', y='tip_pct', row='time', 
#                col='smoker', kind='bar', 
#                data=tips[tips.tip_pct < 1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/saulo/Arquivos/anotacoes/analise de dados/cap9.ipynb Cell 79 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/saulo/Arquivos/anotacoes/analise%20de%20dados/cap9.ipynb#Y164sZmlsZQ%3D%3D?line=0'>1</a> sns.factorplot(x='day', y='tip_pct', row='time',
#       <a href='vscode-notebook-cell:/home/saulo/Arquivos/anotacoes/analise%20de%20dados/cap9.ipynb#Y164sZmlsZQ%3D%3D?line=1'>2</a>                col='smoker', kind='bar',
#       <a href='vscode-notebook-cell:/home/saulo/Arquivos/anotacoes/analise%20de%20dados/cap9.ipynb#Y164sZmlsZQ%3D%3D?line=2'>3</a>                data=tips[tips.tip_pct < 1])
#
# AttributeError: module 'seaborn' has no attribute 'factorplot'

# %%
# sns.factorplot(x='tip_pct', y='day', kind='box',
#                data=tips[tips.tip_pct < 0.5])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/saulo/Arquivos/anotacoes/analise de dados/cap9.ipynb Cell 80 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/saulo/Arquivos/anotacoes/analise%20de%20dados/cap9.ipynb#Y165sZmlsZQ%3D%3D?line=0'>1</a> sns.factorplot(x='tip_pct', y='day', kind='box',
#       <a href='vscode-notebook-cell:/home/saulo/Arquivos/anotacoes/analise%20de%20dados/cap9.ipynb#Y165sZmlsZQ%3D%3D?line=1'>2</a>                data=tips[tips.tip_pct < 0.5])
#
# AttributeError: module 'seaborn' has no attribute 'factorplot'
